# %% [markdown]
# Nama Lengkap : Nazarul Bagus Riyadi
#
# NIM : 240401010229
#
# Kelas : IF404
#
# ---
#
# # Praktikum Pertemuan 1: Pengenalan Data Science

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel & tipe data
nama     = "Nazarul Bagus Riyadi"
angkatan = 2024
ipk      = 3.98
aktif    = True

print(f"Halo, {nama} angkatan {angkatan}!")
print(f"IPK : {ipk} | Aktif : {aktif}")

# SEL 3: List & perulangan
tools = ["Python", "Colab", "Jupyter", "GitHub"]
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Nazarul Bagus Riyadi", "PJJ Informatika", 2024))
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Halo, Nazarul Bagus Riyadi angkatan 2024!
# IPK : 3.98 | Aktif : True
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub
# Nazarul Bagus Riyadi | PJJ Informatika | 2024

# %% [markdown]
# ## Kesimpulan
#
# ### Apa yang Dipelajari
# - Dasar notebook Jupyter/Colab: menjalankan sel kode dan markdown
# - Variabel, tipe data, list, perulangan, dan fungsi Python sederhana
# - Cara mendokumentasikan identitas dan hasil praktikum di notebook
#
# ### Temuan Utama
# - Python cocok sebagai bahasa pertama untuk Data Science karena sintaksnya mudah dibaca
# - Notebook memudahkan kombinasi kode, output, dan penjelasan dalam satu file
# - Struktur dasar (variabel → loop → fungsi) menjadi fondasi pertemuan selanjutnya
#
# ### Keterbatasan
# - Belum menyentuh manipulasi data atau visualisasi
# - Perlu latihan lebih banyak sebelum pindah ke Pandas dan analisis data
